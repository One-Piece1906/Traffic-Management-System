# %%
#only red and green
import time

def traffic_signal():
    # Define the directions and their respective durations in seconds
    directions = [
        {"name": "North", "duration": 10},
        {"name": "East", "duration": 10},
        {"name": "South", "duration": 10},
        {"name": "West", "duration": 10}
    ]

    while True:
        for i, direction in enumerate(directions):
            for t in range(direction["duration"], 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: GREEN ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(directions[(i + 1 + k) % len(directions)]["duration"] for k in range(cycle_offset))
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t} seconds)")

                # Wait for 1 second
                time.sleep(1)

if __name__ == "__main__":
    try:
        traffic_signal()
    except KeyboardInterrupt:
        print("\nTraffic signal simulation ended.")

# %%
#Implementation of basic traffic simulation with red, orange and green times
import time

def traffic_signal():
    # Define the directions and their respective durations in seconds
    directions = [
        {"name": "North", "duration": 60},
        {"name": "East", "duration": 60},
        {"name": "South", "duration": 60},
        {"name": "West", "duration": 60}
    ]

    orange_duration = 3  # Duration for the orange signal

    while True:
        for i, direction in enumerate(directions):
            # Handle green signal
            for t in range(direction["duration"], 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: GREEN ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(directions[(i + 1 + k) % len(directions)]["duration"] for k in range(cycle_offset)) + orange_duration
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t} seconds)")

                # Wait for 1 second
                time.sleep(1)

            # Handle orange signal
            for t in range(orange_duration, 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: ORANGE ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(directions[(i + 1 + k) % len(directions)]["duration"] for k in range(cycle_offset)) + orange_duration
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t - orange_duration} seconds)")

                # Wait for 1 second
                time.sleep(1)

if __name__ == "__main__":
    try:
        traffic_signal()
    except KeyboardInterrupt:
        print("\nTraffic signal simulation ended.")
# Out:
# Traffic Signal Status:
# North: GREEN (60 seconds left)
# East: RED (Waiting: 63 seconds)
# South: RED (Waiting: 123 seconds)
# West: RED (Waiting: 183 seconds)
# Traffic Signal Status:
# North: GREEN (59 seconds left)
# East: RED (Waiting: 62 seconds)
# South: RED (Waiting: 122 seconds)
# West: RED (Waiting: 182 seconds)
# Traffic Signal Status:
# North: GREEN (58 seconds left)
# East: RED (Waiting: 61 seconds)
# South: RED (Waiting: 121 seconds)
# West: RED (Waiting: 181 seconds)
# Traffic Signal Status:
# North: GREEN (57 seconds left)
# East: RED (Waiting: 60 seconds)
# South: RED (Waiting: 120 seconds)
# West: RED (Waiting: 180 seconds)
# Traffic Signal Status:
# North: GREEN (56 seconds left)
# East: RED (Waiting: 59 seconds)
# South: RED (Waiting: 119 seconds)
# West: RED (Waiting: 179 seconds)
# Traffic Signal Status:
# North: GREEN (55 seconds left)
# East: RED (Waiting: 58 seconds)
# South: RED (Waiting: 118 seconds)
# West: RED (Waiting: 178 seconds)
# Traffic Signal Status:
# North: GREEN (54 seconds left)
# East: RED (Waiting: 57 seconds)
# South: RED (Waiting: 117 seconds)
# West: RED (Waiting: 177 seconds)
# Traffic Signal Status:
# North: GREEN (53 seconds left)
# East: RED (Waiting: 56 seconds)
# South: RED (Waiting: 116 seconds)
# West: RED (Waiting: 176 seconds)
# Traffic Signal Status:
# North: GREEN (52 seconds left)
# East: RED (Waiting: 55 seconds)
# South: RED (Waiting: 115 seconds)
# West: RED (Waiting: 175 seconds)
# Traffic Signal Status:
# North: GREEN (51 seconds left)
# East: RED (Waiting: 54 seconds)
# South: RED (Waiting: 114 seconds)
# West: RED (Waiting: 174 seconds)
# Traffic Signal Status:
# North: GREEN (50 seconds left)
# East: RED (Waiting: 53 seconds)
# South: RED (Waiting: 113 seconds)
# West: RED (Waiting: 173 seconds)
# Traffic Signal Status:
# North: GREEN (49 seconds left)
# East: RED (Waiting: 52 seconds)
# South: RED (Waiting: 112 seconds)
# West: RED (Waiting: 172 seconds)
# Traffic Signal Status:
# North: GREEN (48 seconds left)
# East: RED (Waiting: 51 seconds)
# South: RED (Waiting: 111 seconds)
# West: RED (Waiting: 171 seconds)
# Traffic Signal Status:
# North: GREEN (47 seconds left)
# East: RED (Waiting: 50 seconds)
# South: RED (Waiting: 110 seconds)
# West: RED (Waiting: 170 seconds)
# Traffic Signal Status:
# North: GREEN (46 seconds left)
# East: RED (Waiting: 49 seconds)
# South: RED (Waiting: 109 seconds)
# West: RED (Waiting: 169 seconds)
# Traffic Signal Status:
# North: GREEN (45 seconds left)
# East: RED (Waiting: 48 seconds)
# South: RED (Waiting: 108 seconds)
# West: RED (Waiting: 168 seconds)
# Traffic Signal Status:
# North: GREEN (44 seconds left)
# East: RED (Waiting: 47 seconds)
# South: RED (Waiting: 107 seconds)
# West: RED (Waiting: 167 seconds)
# Traffic Signal Status:
# North: GREEN (43 seconds left)
# East: RED (Waiting: 46 seconds)
# South: RED (Waiting: 106 seconds)
# West: RED (Waiting: 166 seconds)
# Traffic Signal Status:
# North: GREEN (42 seconds left)
# East: RED (Waiting: 45 seconds)
# South: RED (Waiting: 105 seconds)
# West: RED (Waiting: 165 seconds)
# Traffic Signal Status:
# North: GREEN (41 seconds left)
# East: RED (Waiting: 44 seconds)
# South: RED (Waiting: 104 seconds)
# West: RED (Waiting: 164 seconds)
# Traffic Signal Status:
# North: GREEN (40 seconds left)
# East: RED (Waiting: 43 seconds)
# South: RED (Waiting: 103 seconds)
# West: RED (Waiting: 163 seconds)
# Traffic Signal Status:
# North: GREEN (39 seconds left)
# East: RED (Waiting: 42 seconds)
# South: RED (Waiting: 102 seconds)
# West: RED (Waiting: 162 seconds)
# Traffic Signal Status:
# North: GREEN (38 seconds left)
# East: RED (Waiting: 41 seconds)
# South: RED (Waiting: 101 seconds)
# West: RED (Waiting: 161 seconds)
# Traffic Signal Status:
# North: GREEN (37 seconds left)
# East: RED (Waiting: 40 seconds)
# South: RED (Waiting: 100 seconds)
# West: RED (Waiting: 160 seconds)
# Traffic Signal Status:
# North: GREEN (36 seconds left)
# East: RED (Waiting: 39 seconds)
# South: RED (Waiting: 99 seconds)
# West: RED (Waiting: 159 seconds)
# Traffic Signal Status:
# North: GREEN (35 seconds left)
# East: RED (Waiting: 38 seconds)
# South: RED (Waiting: 98 seconds)
# West: RED (Waiting: 158 seconds)
# Traffic Signal Status:
# North: GREEN (34 seconds left)
# East: RED (Waiting: 37 seconds)
# South: RED (Waiting: 97 seconds)
# West: RED (Waiting: 157 seconds)
# Traffic Signal Status:
# North: GREEN (33 seconds left)
# East: RED (Waiting: 36 seconds)
# South: RED (Waiting: 96 seconds)
# West: RED (Waiting: 156 seconds)
# Traffic Signal Status:
# North: GREEN (32 seconds left)
# East: RED (Waiting: 35 seconds)
# South: RED (Waiting: 95 seconds)
# West: RED (Waiting: 155 seconds)
# Traffic Signal Status:
# North: GREEN (31 seconds left)
# East: RED (Waiting: 34 seconds)
# South: RED (Waiting: 94 seconds)
# West: RED (Waiting: 154 seconds)
# Traffic Signal Status:
# North: GREEN (30 seconds left)
# East: RED (Waiting: 33 seconds)
# South: RED (Waiting: 93 seconds)
# West: RED (Waiting: 153 seconds)
# Traffic Signal Status:
# North: GREEN (29 seconds left)
# East: RED (Waiting: 32 seconds)
# South: RED (Waiting: 92 seconds)
# West: RED (Waiting: 152 seconds)
# Traffic Signal Status:
# North: GREEN (28 seconds left)
# East: RED (Waiting: 31 seconds)
# South: RED (Waiting: 91 seconds)
# West: RED (Waiting: 151 seconds)
# Traffic Signal Status:
# North: GREEN (27 seconds left)
# East: RED (Waiting: 30 seconds)
# South: RED (Waiting: 90 seconds)
# West: RED (Waiting: 150 seconds)
# Traffic Signal Status:
# North: GREEN (26 seconds left)
# East: RED (Waiting: 29 seconds)
# South: RED (Waiting: 89 seconds)
# West: RED (Waiting: 149 seconds)
# Traffic Signal Status:
# North: GREEN (25 seconds left)
# East: RED (Waiting: 28 seconds)
# South: RED (Waiting: 88 seconds)
# West: RED (Waiting: 148 seconds)
# Traffic Signal Status:
# North: GREEN (24 seconds left)
# East: RED (Waiting: 27 seconds)
# South: RED (Waiting: 87 seconds)
# West: RED (Waiting: 147 seconds)
# Traffic Signal Status:
# North: GREEN (23 seconds left)
# East: RED (Waiting: 26 seconds)
# South: RED (Waiting: 86 seconds)
# West: RED (Waiting: 146 seconds)
# Traffic Signal Status:
# North: GREEN (22 seconds left)
# East: RED (Waiting: 25 seconds)
# South: RED (Waiting: 85 seconds)
# West: RED (Waiting: 145 seconds)
# Traffic Signal Status:
# North: GREEN (21 seconds left)
# East: RED (Waiting: 24 seconds)
# South: RED (Waiting: 84 seconds)
# West: RED (Waiting: 144 seconds)
# Traffic Signal Status:
# North: GREEN (20 seconds left)
# East: RED (Waiting: 23 seconds)
# South: RED (Waiting: 83 seconds)
# West: RED (Waiting: 143 seconds)
# Traffic Signal Status:
# North: GREEN (19 seconds left)
# East: RED (Waiting: 22 seconds)
# South: RED (Waiting: 82 seconds)
# West: RED (Waiting: 142 seconds)
# Traffic Signal Status:
# North: GREEN (18 seconds left)
# East: RED (Waiting: 21 seconds)
# South: RED (Waiting: 81 seconds)
# West: RED (Waiting: 141 seconds)
# Traffic Signal Status:
# North: GREEN (17 seconds left)
# East: RED (Waiting: 20 seconds)
# South: RED (Waiting: 80 seconds)
# West: RED (Waiting: 140 seconds)
# Traffic Signal Status:
# North: GREEN (16 seconds left)
# East: RED (Waiting: 19 seconds)
# South: RED (Waiting: 79 seconds)
# West: RED (Waiting: 139 seconds)
# Traffic Signal Status:
# North: GREEN (15 seconds left)
# East: RED (Waiting: 18 seconds)
# South: RED (Waiting: 78 seconds)
# West: RED (Waiting: 138 seconds)
# Traffic Signal Status:
# North: GREEN (14 seconds left)
# East: RED (Waiting: 17 seconds)
# South: RED (Waiting: 77 seconds)
# West: RED (Waiting: 137 seconds)
# Traffic Signal Status:
# North: GREEN (13 seconds left)
# East: RED (Waiting: 16 seconds)
# South: RED (Waiting: 76 seconds)
# West: RED (Waiting: 136 seconds)
# Traffic Signal Status:
# North: GREEN (12 seconds left)
# East: RED (Waiting: 15 seconds)
# South: RED (Waiting: 75 seconds)
# West: RED (Waiting: 135 seconds)
# Traffic Signal Status:
# North: GREEN (11 seconds left)
# East: RED (Waiting: 14 seconds)
# South: RED (Waiting: 74 seconds)
# West: RED (Waiting: 134 seconds)
# Traffic Signal Status:
# North: GREEN (10 seconds left)
# East: RED (Waiting: 13 seconds)
# South: RED (Waiting: 73 seconds)
# West: RED (Waiting: 133 seconds)
# Traffic Signal Status:
# North: GREEN (9 seconds left)
# East: RED (Waiting: 12 seconds)
# South: RED (Waiting: 72 seconds)
# West: RED (Waiting: 132 seconds)
# Traffic Signal Status:
# North: GREEN (8 seconds left)
# East: RED (Waiting: 11 seconds)
# South: RED (Waiting: 71 seconds)
# West: RED (Waiting: 131 seconds)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#Simulation based on our metrics
import time
import json

def load_traffic_data(file_path):
    """Load traffic signal data from a JSON file."""
    with open(file_path, 'r') as file:
        return json.load(file)

def traffic_signal(data):
    # Parse directions and their durations from the data
    directions = [
        {"name": direction, "green": info["Green"], "orange": info["Orange"]}
        for direction, info in data.items()
    ]

    while True:
        for i, direction in enumerate(directions):
            # Handle green signal
            for t in range(direction["green"], 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: GREEN ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(
                            directions[(i + 1 + k) % len(directions)]["green"] + directions[(i + 1 + k) % len(directions)]["orange"]
                            for k in range(cycle_offset)
                        ) + direction["orange"]
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t} seconds)")

                # Wait for 1 second
                time.sleep(1)

            # Handle orange signal
            for t in range(direction["orange"], 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: ORANGE ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(
                            directions[(i + 1 + k) % len(directions)]["green"] + directions[(i + 1 + k) % len(directions)]["orange"]
                            for k in range(cycle_offset)
                        ) + direction["orange"]
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t - direction['orange']} seconds)")

                # Wait for 1 second
                time.sleep(1)

if __name__ == "__main__":
    try:
        # Load traffic data from the JSON file
        traffic_data = load_traffic_data("C:/Users/Admin/Desktop/Traffic Management System/Backend/traffic_data.json")
        traffic_signal(traffic_data)
    except KeyboardInterrupt:
        print("\nTraffic signal simulation ended.")
    except FileNotFoundError:
        print("Error: traffic_data.json file not found.")
# Out:
# Traffic Signal Status:
# North: ORANGE (3 seconds left)
# South: RED (Waiting: 3 seconds)
# East: RED (Waiting: 32 seconds)
# West: RED (Waiting: 71 seconds)
# Traffic Signal Status:
# North: ORANGE (2 seconds left)
# South: RED (Waiting: 2 seconds)
# East: RED (Waiting: 31 seconds)
# West: RED (Waiting: 70 seconds)
# Traffic Signal Status:
# North: ORANGE (1 seconds left)
# South: RED (Waiting: 1 seconds)
# East: RED (Waiting: 30 seconds)
# West: RED (Waiting: 69 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 117 seconds)
# South: GREEN (26 seconds left)
# East: RED (Waiting: 29 seconds)
# West: RED (Waiting: 68 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 116 seconds)
# South: GREEN (25 seconds left)
# East: RED (Waiting: 28 seconds)
# West: RED (Waiting: 67 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 115 seconds)
# South: GREEN (24 seconds left)
# East: RED (Waiting: 27 seconds)
# West: RED (Waiting: 66 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 114 seconds)
# South: GREEN (23 seconds left)
# East: RED (Waiting: 26 seconds)
# West: RED (Waiting: 65 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 113 seconds)
# South: GREEN (22 seconds left)
# East: RED (Waiting: 25 seconds)
# West: RED (Waiting: 64 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 112 seconds)
# South: GREEN (21 seconds left)
# East: RED (Waiting: 24 seconds)
# West: RED (Waiting: 63 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 111 seconds)
# South: GREEN (20 seconds left)
# East: RED (Waiting: 23 seconds)
# West: RED (Waiting: 62 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 110 seconds)
# South: GREEN (19 seconds left)
# East: RED (Waiting: 22 seconds)
# West: RED (Waiting: 61 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 109 seconds)
# South: GREEN (18 seconds left)
# East: RED (Waiting: 21 seconds)
# West: RED (Waiting: 60 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 108 seconds)
# South: GREEN (17 seconds left)
# East: RED (Waiting: 20 seconds)
# West: RED (Waiting: 59 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 107 seconds)
# South: GREEN (16 seconds left)
# East: RED (Waiting: 19 seconds)
# West: RED (Waiting: 58 seconds)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#Y

import time
import json

def load_traffic_data(file_path):
    """Load traffic signal data from a JSON file."""
    with open(file_path, 'r') as file:
        return json.load(file)

def traffic_signal(data):
    # Parse directions and their durations from the data
    directions = [
        {"name": direction["direction"], "green": direction["green_time"], "orange": direction["orange_time"]}
        for direction in data
    ]

    while True:
        for i, direction in enumerate(directions):
            # Handle green signal
            for t in range(int(direction["green"]), 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: GREEN ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(
                            directions[(i + 1 + k) % len(directions)]["green"] + directions[(i + 1 + k) % len(directions)]["orange"]
                            for k in range(cycle_offset)
                        ) + direction["orange"]
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t} seconds)")

                # Wait for 1 second
                time.sleep(1)

            # Handle orange signal
            for t in range(int(direction["orange"]), 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: ORANGE ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(
                            directions[(i + 1 + k) % len(directions)]["green"] + directions[(i + 1 + k) % len(directions)]["orange"]
                            for k in range(cycle_offset)
                        ) + direction["orange"]
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t - direction['orange']} seconds)")

                # Wait for 1 second
                time.sleep(1)

if __name__ == "__main__":
    try:
        # Load traffic data from the JSON file
        traffic_data = load_traffic_data("C:/Users/Admin/Desktop/Traffic Management System/traffic_timings_y.json")
        traffic_signal(traffic_data)
    except KeyboardInterrupt:
        print("\nTraffic signal simulation ended.")
    except FileNotFoundError:
        print("Error: traffic_data.json file not found.")
# Out:
# Traffic Signal Status:
# North: GREEN (36 seconds left)
# South: RED (Waiting: 39 seconds)
# East: RED (Waiting: 79.65 seconds)
# Traffic Signal Status:
# North: GREEN (35 seconds left)
# South: RED (Waiting: 38 seconds)
# East: RED (Waiting: 78.65 seconds)
# Traffic Signal Status:
# North: GREEN (34 seconds left)
# South: RED (Waiting: 37 seconds)
# East: RED (Waiting: 77.65 seconds)
# Traffic Signal Status:
# North: GREEN (33 seconds left)
# South: RED (Waiting: 36 seconds)
# East: RED (Waiting: 76.65 seconds)
# Traffic Signal Status:
# North: GREEN (32 seconds left)
# South: RED (Waiting: 35 seconds)
# East: RED (Waiting: 75.65 seconds)
# Traffic Signal Status:
# North: GREEN (31 seconds left)
# South: RED (Waiting: 34 seconds)
# East: RED (Waiting: 74.65 seconds)
# Traffic Signal Status:
# North: GREEN (30 seconds left)
# South: RED (Waiting: 33 seconds)
# East: RED (Waiting: 73.65 seconds)
# Traffic Signal Status:
# North: GREEN (29 seconds left)
# South: RED (Waiting: 32 seconds)
# East: RED (Waiting: 72.65 seconds)
# Traffic Signal Status:
# North: GREEN (28 seconds left)
# South: RED (Waiting: 31 seconds)
# East: RED (Waiting: 71.65 seconds)
# Traffic Signal Status:
# North: GREEN (27 seconds left)
# South: RED (Waiting: 30 seconds)
# East: RED (Waiting: 70.65 seconds)
# Traffic Signal Status:
# North: GREEN (26 seconds left)
# South: RED (Waiting: 29 seconds)
# East: RED (Waiting: 69.65 seconds)
# Traffic Signal Status:
# North: GREEN (25 seconds left)
# South: RED (Waiting: 28 seconds)
# East: RED (Waiting: 68.65 seconds)
# Traffic Signal Status:
# North: GREEN (24 seconds left)
# South: RED (Waiting: 27 seconds)
# East: RED (Waiting: 67.65 seconds)
# Traffic Signal Status:
# North: GREEN (23 seconds left)
# South: RED (Waiting: 26 seconds)
# East: RED (Waiting: 66.65 seconds)
# Traffic Signal Status:
# North: GREEN (22 seconds left)
# South: RED (Waiting: 25 seconds)
# East: RED (Waiting: 65.65 seconds)
# Traffic Signal Status:
# North: GREEN (21 seconds left)
# South: RED (Waiting: 24 seconds)
# East: RED (Waiting: 64.65 seconds)
# Traffic Signal Status:
# North: GREEN (20 seconds left)
# South: RED (Waiting: 23 seconds)
# East: RED (Waiting: 63.65 seconds)
# Traffic Signal Status:
# North: GREEN (19 seconds left)
# South: RED (Waiting: 22 seconds)
# East: RED (Waiting: 62.65 seconds)
# Traffic Signal Status:
# North: GREEN (18 seconds left)
# South: RED (Waiting: 21 seconds)
# East: RED (Waiting: 61.65 seconds)
# Traffic Signal Status:
# North: GREEN (17 seconds left)
# South: RED (Waiting: 20 seconds)
# East: RED (Waiting: 60.65 seconds)
# Traffic Signal Status:
# North: GREEN (16 seconds left)
# South: RED (Waiting: 19 seconds)
# East: RED (Waiting: 59.65 seconds)
# Traffic Signal Status:
# North: GREEN (15 seconds left)
# South: RED (Waiting: 18 seconds)
# East: RED (Waiting: 58.65 seconds)
# Traffic Signal Status:
# North: GREEN (14 seconds left)
# South: RED (Waiting: 17 seconds)
# East: RED (Waiting: 57.65 seconds)
# Traffic Signal Status:
# North: GREEN (13 seconds left)
# South: RED (Waiting: 16 seconds)
# East: RED (Waiting: 56.65 seconds)
# Traffic Signal Status:
# North: GREEN (12 seconds left)
# South: RED (Waiting: 15 seconds)
# East: RED (Waiting: 55.65 seconds)
# Traffic Signal Status:
# North: GREEN (11 seconds left)
# South: RED (Waiting: 14 seconds)
# East: RED (Waiting: 54.65 seconds)
# Traffic Signal Status:
# North: GREEN (10 seconds left)
# South: RED (Waiting: 13 seconds)
# East: RED (Waiting: 53.65 seconds)
# Traffic Signal Status:
# North: GREEN (9 seconds left)
# South: RED (Waiting: 12 seconds)
# East: RED (Waiting: 52.65 seconds)
# Traffic Signal Status:
# North: GREEN (8 seconds left)
# South: RED (Waiting: 11 seconds)
# East: RED (Waiting: 51.65 seconds)
# Traffic Signal Status:
# North: GREEN (7 seconds left)
# South: RED (Waiting: 10 seconds)
# East: RED (Waiting: 50.65 seconds)
# Traffic Signal Status:
# North: GREEN (6 seconds left)
# South: RED (Waiting: 9 seconds)
# East: RED (Waiting: 49.65 seconds)
# Traffic Signal Status:
# North: GREEN (5 seconds left)
# South: RED (Waiting: 8 seconds)
# East: RED (Waiting: 48.65 seconds)
# Traffic Signal Status:
# North: GREEN (4 seconds left)
# South: RED (Waiting: 7 seconds)
# East: RED (Waiting: 47.65 seconds)
# Traffic Signal Status:
# North: GREEN (3 seconds left)
# South: RED (Waiting: 6 seconds)
# East: RED (Waiting: 46.65 seconds)
# Traffic Signal Status:
# North: GREEN (2 seconds left)
# South: RED (Waiting: 5 seconds)
# East: RED (Waiting: 45.65 seconds)
# Traffic Signal Status:
# North: GREEN (1 seconds left)
# South: RED (Waiting: 4 seconds)
# East: RED (Waiting: 44.65 seconds)
# Traffic Signal Status:
# North: ORANGE (3 seconds left)
# South: RED (Waiting: 3 seconds)
# East: RED (Waiting: 43.65 seconds)
# Traffic Signal Status:
# North: ORANGE (2 seconds left)
# South: RED (Waiting: 2 seconds)
# East: RED (Waiting: 42.65 seconds)
# Traffic Signal Status:
# North: ORANGE (1 seconds left)
# South: RED (Waiting: 1 seconds)
# East: RED (Waiting: 41.65 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 79.53999999999999 seconds)
# South: GREEN (37 seconds left)
# East: RED (Waiting: 40 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 78.53999999999999 seconds)
# South: GREEN (36 seconds left)
# East: RED (Waiting: 39 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 77.53999999999999 seconds)
# South: GREEN (35 seconds left)
# East: RED (Waiting: 38 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 76.53999999999999 seconds)
# South: GREEN (34 seconds left)
# East: RED (Waiting: 37 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 75.53999999999999 seconds)
# South: GREEN (33 seconds left)
# East: RED (Waiting: 36 seconds)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import time
import json

def load_traffic_data(file_path):
    """Load traffic signal data from a JSON file."""
    with open(file_path, 'r') as file:
        return json.load(file)

def traffic_signal(data):
    # Parse directions and their durations from the data
    directions = [
        {"name": direction["direction"], "green": direction["green_time"], "orange": direction["orange_time"]}
        for direction in data
    ]

    while True:
        for i, direction in enumerate(directions):
            # Handle green signal
            for t in range(int(direction["green"]), 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: GREEN ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(
                            directions[(i + 1 + k) % len(directions)]["green"] + directions[(i + 1 + k) % len(directions)]["orange"]
                            for k in range(cycle_offset)
                        ) + direction["orange"]
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t} seconds)")

                # Wait for 1 second
                time.sleep(1)

            # Handle orange signal
            for t in range(int(direction["orange"]), 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: ORANGE ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(
                            directions[(i + 1 + k) % len(directions)]["green"] + directions[(i + 1 + k) % len(directions)]["orange"]
                            for k in range(cycle_offset)
                        ) + direction["orange"]
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t - direction['orange']} seconds)")

                # Wait for 1 second
                time.sleep(1)

if __name__ == "__main__":
    try:
        # Load traffic data from the JSON file
        traffic_data = load_traffic_data("C:/Users/Admin/Desktop/Traffic Management System/traffic_timings_u.json")
        traffic_signal(traffic_data)
    except KeyboardInterrupt:
        print("\nTraffic signal simulation ended.")
    except FileNotFoundError:
        print("Error: uturn_traffic_data.json file not found.")
# Out:
# Traffic Signal Status:
# North: GREEN (23 seconds left)
# South: RED (Waiting: 26 seconds)
# East: RED (Waiting: 52.84 seconds)
# West: RED (Waiting: 78.98 seconds)
# U-Turn: RED (Waiting: 104.75 seconds)
# Traffic Signal Status:
# North: GREEN (22 seconds left)
# South: RED (Waiting: 25 seconds)
# East: RED (Waiting: 51.84 seconds)
# West: RED (Waiting: 77.98 seconds)
# U-Turn: RED (Waiting: 103.75 seconds)
# Traffic Signal Status:
# North: GREEN (21 seconds left)
# South: RED (Waiting: 24 seconds)
# East: RED (Waiting: 50.84 seconds)
# West: RED (Waiting: 76.98 seconds)
# U-Turn: RED (Waiting: 102.75 seconds)
# Traffic Signal Status:
# North: GREEN (20 seconds left)
# South: RED (Waiting: 23 seconds)
# East: RED (Waiting: 49.84 seconds)
# West: RED (Waiting: 75.98 seconds)
# U-Turn: RED (Waiting: 101.75 seconds)
# Traffic Signal Status:
# North: GREEN (19 seconds left)
# South: RED (Waiting: 22 seconds)
# East: RED (Waiting: 48.84 seconds)
# West: RED (Waiting: 74.98 seconds)
# U-Turn: RED (Waiting: 100.75 seconds)
# Traffic Signal Status:
# North: GREEN (18 seconds left)
# South: RED (Waiting: 21 seconds)
# East: RED (Waiting: 47.84 seconds)
# West: RED (Waiting: 73.98 seconds)
# U-Turn: RED (Waiting: 99.75 seconds)
# Traffic Signal Status:
# North: GREEN (17 seconds left)
# South: RED (Waiting: 20 seconds)
# East: RED (Waiting: 46.84 seconds)
# West: RED (Waiting: 72.98 seconds)
# U-Turn: RED (Waiting: 98.75 seconds)
# Traffic Signal Status:
# North: GREEN (16 seconds left)
# South: RED (Waiting: 19 seconds)
# East: RED (Waiting: 45.84 seconds)
# West: RED (Waiting: 71.98 seconds)
# U-Turn: RED (Waiting: 97.75 seconds)
# Traffic Signal Status:
# North: GREEN (15 seconds left)
# South: RED (Waiting: 18 seconds)
# East: RED (Waiting: 44.84 seconds)
# West: RED (Waiting: 70.98 seconds)
# U-Turn: RED (Waiting: 96.75 seconds)
# Traffic Signal Status:
# North: GREEN (14 seconds left)
# South: RED (Waiting: 17 seconds)
# East: RED (Waiting: 43.84 seconds)
# West: RED (Waiting: 69.98 seconds)
# U-Turn: RED (Waiting: 95.75 seconds)
# Traffic Signal Status:
# North: GREEN (13 seconds left)
# South: RED (Waiting: 16 seconds)
# East: RED (Waiting: 42.84 seconds)
# West: RED (Waiting: 68.98 seconds)
# U-Turn: RED (Waiting: 94.75 seconds)
# Traffic Signal Status:
# North: GREEN (12 seconds left)
# South: RED (Waiting: 15 seconds)
# East: RED (Waiting: 41.84 seconds)
# West: RED (Waiting: 67.98 seconds)
# U-Turn: RED (Waiting: 93.75 seconds)
# Traffic Signal Status:
# North: GREEN (11 seconds left)
# South: RED (Waiting: 14 seconds)
# East: RED (Waiting: 40.84 seconds)
# West: RED (Waiting: 66.98 seconds)
# U-Turn: RED (Waiting: 92.75 seconds)
# Traffic Signal Status:
# North: GREEN (10 seconds left)
# South: RED (Waiting: 13 seconds)
# East: RED (Waiting: 39.84 seconds)
# West: RED (Waiting: 65.98 seconds)
# U-Turn: RED (Waiting: 91.75 seconds)
# Traffic Signal Status:
# North: GREEN (9 seconds left)
# South: RED (Waiting: 12 seconds)
# East: RED (Waiting: 38.84 seconds)
# West: RED (Waiting: 64.98 seconds)
# U-Turn: RED (Waiting: 90.75 seconds)
# Traffic Signal Status:
# North: GREEN (8 seconds left)
# South: RED (Waiting: 11 seconds)
# East: RED (Waiting: 37.84 seconds)
# West: RED (Waiting: 63.980000000000004 seconds)
# U-Turn: RED (Waiting: 89.75 seconds)
# Traffic Signal Status:
# North: GREEN (7 seconds left)
# South: RED (Waiting: 10 seconds)
# East: RED (Waiting: 36.84 seconds)
# West: RED (Waiting: 62.980000000000004 seconds)
# U-Turn: RED (Waiting: 88.75 seconds)
# Traffic Signal Status:
# North: GREEN (6 seconds left)
# South: RED (Waiting: 9 seconds)
# East: RED (Waiting: 35.84 seconds)
# West: RED (Waiting: 61.980000000000004 seconds)
# U-Turn: RED (Waiting: 87.75 seconds)
# Traffic Signal Status:
# North: GREEN (5 seconds left)
# South: RED (Waiting: 8 seconds)
# East: RED (Waiting: 34.84 seconds)
# West: RED (Waiting: 60.980000000000004 seconds)
# U-Turn: RED (Waiting: 86.75 seconds)
# Traffic Signal Status:
# North: GREEN (4 seconds left)
# South: RED (Waiting: 7 seconds)
# East: RED (Waiting: 33.84 seconds)
# West: RED (Waiting: 59.980000000000004 seconds)
# U-Turn: RED (Waiting: 85.75 seconds)
# Traffic Signal Status:
# North: GREEN (3 seconds left)
# South: RED (Waiting: 6 seconds)
# East: RED (Waiting: 32.84 seconds)
# West: RED (Waiting: 58.980000000000004 seconds)
# U-Turn: RED (Waiting: 84.75 seconds)
# Traffic Signal Status:
# North: GREEN (2 seconds left)
# South: RED (Waiting: 5 seconds)
# East: RED (Waiting: 31.84 seconds)
# West: RED (Waiting: 57.980000000000004 seconds)
# U-Turn: RED (Waiting: 83.75 seconds)
# Traffic Signal Status:
# North: GREEN (1 seconds left)
# South: RED (Waiting: 4 seconds)
# East: RED (Waiting: 30.84 seconds)
# West: RED (Waiting: 56.980000000000004 seconds)
# U-Turn: RED (Waiting: 82.75 seconds)
# Traffic Signal Status:
# North: ORANGE (3 seconds left)
# South: RED (Waiting: 3 seconds)
# East: RED (Waiting: 29.840000000000003 seconds)
# West: RED (Waiting: 55.980000000000004 seconds)
# U-Turn: RED (Waiting: 81.75 seconds)
# Traffic Signal Status:
# North: ORANGE (2 seconds left)
# South: RED (Waiting: 2 seconds)
# East: RED (Waiting: 28.84 seconds)
# West: RED (Waiting: 54.980000000000004 seconds)
# U-Turn: RED (Waiting: 80.75 seconds)
# Traffic Signal Status:
# North: ORANGE (1 seconds left)
# South: RED (Waiting: 1 seconds)
# East: RED (Waiting: 27.84 seconds)
# West: RED (Waiting: 53.980000000000004 seconds)
# U-Turn: RED (Waiting: 79.75 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 92.84 seconds)
# South: GREEN (23 seconds left)
# East: RED (Waiting: 26 seconds)
# West: RED (Waiting: 52.14 seconds)
# U-Turn: RED (Waiting: 77.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 91.84 seconds)
# South: GREEN (22 seconds left)
# East: RED (Waiting: 25 seconds)
# West: RED (Waiting: 51.14 seconds)
# U-Turn: RED (Waiting: 76.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 90.84 seconds)
# South: GREEN (21 seconds left)
# East: RED (Waiting: 24 seconds)
# West: RED (Waiting: 50.14 seconds)
# U-Turn: RED (Waiting: 75.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 89.84 seconds)
# South: GREEN (20 seconds left)
# East: RED (Waiting: 23 seconds)
# West: RED (Waiting: 49.14 seconds)
# U-Turn: RED (Waiting: 74.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 88.84 seconds)
# South: GREEN (19 seconds left)
# East: RED (Waiting: 22 seconds)
# West: RED (Waiting: 48.14 seconds)
# U-Turn: RED (Waiting: 73.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 87.84 seconds)
# South: GREEN (18 seconds left)
# East: RED (Waiting: 21 seconds)
# West: RED (Waiting: 47.14 seconds)
# U-Turn: RED (Waiting: 72.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 86.84 seconds)
# South: GREEN (17 seconds left)
# East: RED (Waiting: 20 seconds)
# West: RED (Waiting: 46.14 seconds)
# U-Turn: RED (Waiting: 71.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 85.84 seconds)
# South: GREEN (16 seconds left)
# East: RED (Waiting: 19 seconds)
# West: RED (Waiting: 45.14 seconds)
# U-Turn: RED (Waiting: 70.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 84.84 seconds)
# South: GREEN (15 seconds left)
# East: RED (Waiting: 18 seconds)
# West: RED (Waiting: 44.14 seconds)
# U-Turn: RED (Waiting: 69.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 83.84 seconds)
# South: GREEN (14 seconds left)
# East: RED (Waiting: 17 seconds)
# West: RED (Waiting: 43.14 seconds)
# U-Turn: RED (Waiting: 68.91 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 82.84 seconds)
# South: GREEN (13 seconds left)
# East: RED (Waiting: 16 seconds)
# West: RED (Waiting: 42.14 seconds)
# U-Turn: RED (Waiting: 67.91 seconds)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
