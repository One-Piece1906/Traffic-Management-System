# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [2]</a>'.</span>

# %%
import sys
import os
import os
print(os.getcwd())

# Add the src directory to the Python path
sys.path.append(os.path.abspath("C:/Users/Admin/Desktop/Traffic Management System/ML/src"))
# Out:
# c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
import os
import cv2
import csv
import numpy as np
from ultralytics import YOLO
from collections import deque
from data_processing import extract_frames
from vehicle_detection import detect_vehicles

# Initialize variables for vehicle tracking
vehicle_positions = {}  # Dictionary to track vehicle positions across frames
vehicle_speeds = deque(maxlen=10)  # Store the speed of tracked vehicles
frame_rate = 2  # Assuming 2 frames per second for speed calculation
previous_vehicles = []  # Placeholder for previous vehicle positions
previous_frame = None  # Placeholder for previous frame

def calculate_average_speed(frame_path, previous_vehicles, previous_frame):
    """Estimate the average speed of vehicles in the frame using vehicle tracking."""
    current_vehicle_count, current_boxes = detect_vehicles(frame_path)

    total_speed = 0
    speed_count = 0

    if previous_frame is not None and len(previous_vehicles) > 0:
        for i, box in enumerate(current_boxes):
            # Extract bounding box coordinates and convert them to float
            x1, y1, x2, y2 = box.xywh[0].tolist()  # Convert Tensor to list and unpack
            current_position = (x1 + x2) / 2  # Take the middle point of the bounding box

            if i < len(previous_vehicles):
                previous_position = previous_vehicles[i]
                speed = abs(current_position - previous_position) * frame_rate  # Speed = distance/time
                total_speed += speed
                speed_count += 1

        if speed_count > 0:
            return round(total_speed / speed_count, 2)
    return 0

def calculate_density(frame_path,vehicle_count):
    """Calculate traffic density in the frame."""
    img = cv2.imread(frame_path)
    height, width, _ = img.shape
    total_area = height * width

    if total_area > 0:
        density = vehicle_count / (total_area / 100000)  # Normalize to vehicles per 100,000 pixels
        return round(density, 6)
    return 0

def calculate_queue_length(frame_path):
    """Estimate the queue length of stationary vehicles in the frame."""
    _, current_boxes = detect_vehicles(frame_path)

    vehicle_positions_in_line = []

    for box in current_boxes:
        # Extract bounding box coordinates and convert to float
        x1, _, x2, _ = box.xywh[0].tolist()  # Use .tolist() to convert Tensor to a list of values
        vehicle_positions_in_line.append((x1 + x2) / 2)  # Take the midpoint of the vehicle

    vehicle_positions_in_line.sort()

    if len(vehicle_positions_in_line) > 1:
        queue_length = (vehicle_positions_in_line[-1] - vehicle_positions_in_line[0]) * 0.02  # Scaling factor
    else:
        queue_length = 0

    return round(queue_length, 2)

# %%
import os
import cv2
import csv
from ultralytics import YOLO
from collections import deque
from data_processing import extract_frames
from vehicle_detection import detect_vehicles
from emergency_detection import detect_emergency_vehicles 

def process_video(video_path, output_frames_folder, output_metrics_folder, model_path="../models/yolo11n.pt", frame_rate=1):
    """
    Process a video to extract frames, calculate metrics (including emergency vehicles), and save results to CSV.
    """
    video_name = os.path.basename(video_path).split('.')[0]
    video_frames_folder = os.path.join(output_frames_folder, video_name)
    video_metrics_folder = os.path.join(output_metrics_folder, video_name)

    # Create necessary folders if not already present
    os.makedirs(video_frames_folder, exist_ok=True)
    os.makedirs(video_metrics_folder, exist_ok=True)
    
    # Step 1: Extract frames from the video
    extract_frames(video_path, video_frames_folder, frame_rate)

    # Step 2: Calculate metrics for each frame and save to CSV
    metrics = []
    previous_vehicles = []
    previous_frame = None

    for frame_file in sorted(os.listdir(video_frames_folder)):  # Ensure frame order
        frame_path = os.path.join(video_frames_folder, frame_file)

        # Calculate metrics
        vehicle_count, current_boxes = detect_vehicles(frame_path, model_path)
        avg_speed = calculate_average_speed(frame_path, previous_vehicles, previous_frame)
        queue_length = calculate_queue_length(frame_path)
        density = calculate_density(frame_path,vehicle_count)

        emergency = detect_emergency_vehicles(frame_path)

        # Append all metrics
        metrics.append({
            "Frame": frame_file,
            "Number_of_Vehicles": vehicle_count,
            "Average_Speed_km/h": avg_speed,
            "Traffic_Density": density,
            "Queue_Length_meters": queue_length,
            "Emergency_Vehicles": emergency
        })

        # Update previous vehicles and previous frame for the next iteration
        previous_vehicles = [(box.xywh[0][0].item() + box.xywh[0][2].item()) / 2 for box in current_boxes]  # Convert tensor to float
        previous_frame = cv2.imread(frame_path)  # Store the current frame as the previous frame

    # Step 3: Save metrics to CSV
    metrics_file_path = os.path.join(video_metrics_folder, f"{video_name}_metrics.csv")
    with open(metrics_file_path, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["Frame", "Number_of_Vehicles", "Average_Speed_km/h", "Traffic_Density", "Queue_Length_meters", "Emergency_Vehicles"])
        writer.writeheader()
        writer.writerows(metrics)
    
    print(f"Metrics for {video_name} saved to {metrics_file_path}")

# %%
video_paths = [
    "../data/videos/video1.mp4", 
    "../data/videos/video2.mp4", 
    "../data/videos/video3.mp4", 
    "../data/videos/video4.mp4"
]

output_frames_folder = "C:/Users/Admin/Desktop/Traffic Management System/ML/outputs/frames"
output_metrics_folder = "C:/Users/Admin/Desktop/Traffic Management System/ML/outputs/metrics"

for video_path in video_paths:
    process_video(video_path, output_frames_folder, output_metrics_folder, frame_rate=1)
# Out:
# Frames extracted to C:/Users/Admin/Desktop/Traffic Management System/ML/outputs/frames\video1
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0000.jpg: 384x640 3 persons, 16 cars, 2 motorcycles, 700.6ms
# Speed: 35.0ms preprocess, 700.6ms inference, 34.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0000.jpg: 384x640 3 persons, 16 cars, 2 motorcycles, 1677.2ms
# Speed: 40.7ms preprocess, 1677.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0000.jpg: 384x640 3 persons, 16 cars, 2 motorcycles, 387.2ms
# Speed: 4.0ms preprocess, 387.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0000.jpg: 384x640 3 cars, 391.2ms
# Speed: 6.6ms preprocess, 391.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0025.jpg: 384x640 5 persons, 17 cars, 4 motorcycles, 1 bus, 2 trucks, 484.1ms
# Speed: 38.7ms preprocess, 484.1ms inference, 54.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0025.jpg: 384x640 5 persons, 17 cars, 4 motorcycles, 1 bus, 2 trucks, 881.6ms
# Speed: 9.6ms preprocess, 881.6ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0025.jpg: 384x640 5 persons, 17 cars, 4 motorcycles, 1 bus, 2 trucks, 497.3ms
# Speed: 8.6ms preprocess, 497.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0025.jpg: 384x640 2 cars, 758.3ms
# Speed: 67.8ms preprocess, 758.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0050.jpg: 384x640 5 persons, 21 cars, 4 motorcycles, 5 trucks, 1201.1ms
# Speed: 23.6ms preprocess, 1201.1ms inference, 58.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0050.jpg: 384x640 5 persons, 21 cars, 4 motorcycles, 5 trucks, 461.4ms
# Speed: 27.2ms preprocess, 461.4ms inference, 19.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0050.jpg: 384x640 5 persons, 21 cars, 4 motorcycles, 5 trucks, 494.8ms
# Speed: 4.7ms preprocess, 494.8ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_0050.jpg: 384x640 3 cars, 1105.0ms
# Speed: 16.2ms preprocess, 1105.0ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video1\frame_
4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_13.jpg: 608x640 1 car, 868.1ms
# Speed: 35.0ms preprocess, 868.1ms inference, 3.1ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_14.jpg: 640x352 1 car, 421.8ms
# Speed: 14.4ms preprocess, 421.8ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_15.jpg: 640x640 1 car, 1976.4ms
# Speed: 25.2ms preprocess, 1976.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_16.jpg: 480x640 1 car, 1051.9ms
# Speed: 16.2ms preprocess, 1051.9ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_17.jpg: 640x480 1 car, 478.4ms
# Speed: 5.6ms preprocess, 478.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_18.jpg: 480x640 1 car, 439.4ms
# Speed: 6.3ms preprocess, 439.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_19.jpg: 640x224 1 car, 453.8ms
# Speed: 15.3ms preprocess, 453.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 224)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_20.jpg: 640x576 1 car, 917.4ms
# Speed: 16.7ms preprocess, 917.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_21.jpg: 544x640 1 car, 355.1ms
# Speed: 31.1ms preprocess, 355.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_22.jpg: 416x640 1 car, 1455.0ms
# Speed: 24.6ms preprocess, 1455.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_23.jpg: 640x640 1 car, 1207.0ms
# Speed: 46.8ms preprocess, 1207.0ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_24.jpg: 640x544 1 car, 1137.3ms
# Speed: 13.0ms preprocess, 1137.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_25.jpg: 640x576 1 car, 890.3ms
# Speed: 18.8ms preprocess, 890.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_26.jpg: 352x640 1 car, 700.2ms
# Speed: 14.3ms preprocess, 700.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_27.jpg: 640x544 1 car, 426.7ms
# Speed: 62.3ms preprocess, 426.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_28.jpg: 640x640 1 car, 680.4ms
# Speed: 36.2ms preprocess, 680.4ms inference, 16.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_29.jpg: 640x576 1 car, 1187.5ms
# Speed: 52.6ms preprocess, 1187.5ms inference, 12.1ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_30.jpg: 608x640 1 car, 1310.2ms
# Speed: 28.6ms preprocess, 1310.2ms inference, 3.0ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_31.jpg: 384x640 1 car, 400.5ms
# Speed: 22.0ms preprocess, 400.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_32.jpg: 352x640 1 car, 477.9ms
# Speed: 30.9ms preprocess, 477.9ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_33.jpg: 640x640 1 car, 588.2ms
# Speed: 14.6ms preprocess, 588.2ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_34.jpg: 640x640 1 car, 851.9ms
# Speed: 23.8ms preprocess, 851.9ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_35.jpg: 640x544 1 car, 715.1ms
# Speed: 21.4ms preprocess, 715.1ms inference, 13.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video2\frame_0150.jpg: 384x640 22 cars, 1 bus, 3 trucks, 841.9ms
# Speed: 23.4ms preprocess, 841.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video2\frame_0150.jpg: 384x640 22 cars, 1 bus, 3 trucks, 614.9ms
# Speed: 10.1ms preprocess, 614.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video2\frame_0150.jpg: 384x640 22 cars, 1 bus, 3 trucks, 390.5ms
# Speed: 8.6ms preprocess, 390.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video2\frame_0150.jpg: 384x640 2 cars, 1 emergency, 1934.5ms
# Speed: 44.0ms preprocess, 1934.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 C:\Users\Admin\Desktop\Traffic Management System\ML\outputs\frames\video2\frame_0150.jpg: 384x640 22 cars, 1 bus, 3 trucks, 623.8ms
# Speed: 18.1ms preprocess, 623.8ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_1.jpg: 448x640 1 car, 587.6ms
# Speed: 12.3ms preprocess, 587.6ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_2.jpg: 576x640 1 car, 1794.3ms
# Speed: 8.9ms preprocess, 1794.3ms inference, 3.0ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_3.jpg: 640x288 1 car, 2618.5ms
# Speed: 24.3ms preprocess, 2618.5ms inference, 15.1ms postprocess per image at shape (1, 3, 640, 288)
#
# image 1/1 c:\Users\Admin\Desktop\Traffic Management System\ML\notebooks\cropped_vehicles\vehicle_4.jpg: 640x640 1 car, 1865.1ms
# Speed: 69.9ms preprocess, 1865.1ms inference, 19.6ms postprocess per image at shape (1, 3, 640, 640)
